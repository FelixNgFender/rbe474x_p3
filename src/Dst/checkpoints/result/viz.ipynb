# %%
import numpy as np
from matplotlib import pyplot as plt

img_array = np.load("epoch_0_patch.npy")
# img is (C, H, W)

plt.imshow(img_array.T)
plt.show()

# %%
import torchvision.transforms.functional as T
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from PIL import Image

epochCount = 779
img_name = f"epoch_{epochCount}_patch"
img_array = np.load(f"{img_name}.npy")
plt.imshow(np.flip(img_array.T, 1))
plt.imsave(f"{img_name}.png", np.flip(img_array.T, 1), cmap=cm.gray)
plt.show()

# %%
img_array0 = np.load("epoch_0_patch.npy")
img_array199 = np.load("epoch_249_patch.npy")

img_diff = img_array199 - img_array0
plt.imshow(img_diff.T)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.96165985..0.9114623].
